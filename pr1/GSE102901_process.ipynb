# %% [markdown]
# <a href="https://colab.research.google.com/github/RuiqingW20/RNA_seq/blob/main/GSE102901_process.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
# !ls -l /content/drive/MyDrive/RNA_proj
# Out:
# total 44696
# drwx------ 2 root root     4096 Aug 13 04:41 breast_cancer
# -rw------- 1 root root 45764381 Aug 13 04:18 GSE102901_TableS1.xlsx

# %%
df = pd.read_excel('/content/drive/MyDrive/RNA_proj/GSE102901_TableS1.xlsx', sheet_name='Sheet2')
# Out:
# /usr/local/lib/python3.11/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df.head(5)
# Out:
#    id1  id2  pos1  pos2 wt1 wt2 mut1 mut2  hd1  hd2  ...   s1_mean   s2_mean  \
# 0  1aA  1aA     1     1   T   I    A    A    1    2  ...  1.019345  0.938943
# 1  1aA  1aD     1     1   T   I    A    D    1    2  ...  1.019345  0.938709
# 2  1aA  1aG     1     1   T   I    A    G    1    2  ...  1.019345  0.918278
# 3  1aA  1aH     1     1   T   I    A    H    1    2  ...  1.019345  0.928834
# 4  1aA  1aM     1     1   T   I    A    M    1    1  ...  1.019345  0.949532
#
#        epi1      epi2      epi3       epi         p       fdr     fdrsd  hit
# 0 -0.042135 -0.076621 -0.052339 -0.057031  0.030690  0.217108  0.004511  0.0
# 1 -0.054132 -0.002190  0.002423 -0.017966  0.426183  0.739068  0.002521  0.0
# 2 -0.002279 -0.025399 -0.021240 -0.016306  0.149000  0.384745  0.003123  0.0
# 3 -0.032355 -0.002110 -0.079923 -0.038129  0.234290  0.503410  0.002947  0.0
# 4 -0.021089 -0.036943 -0.001174 -0.019735  0.196739  0.450635  0.003018  0.0
#
# [5 rows x 48 columns]

# %%
## filter gene with high fdr: as the minimun is 0.0947, set the bar as 0.15
#good umi may be at 450-1500
def significant_gene():
  high_umi = df[]
  significant = df['fdr'] <= 0.15
  meaningful_effect = (abs(df['s1_mean']) >= 0.02) | (abs(df['s2_mean']) >= 0.02)
  data = df[significant & meaningful_effect]
  return data

# %%
significant_gene()
# Out:
#         id1  id2  pos1  pos2 wt1 wt2 mut1 mut2  hd1  hd2  ...   s1_mean  \
# 39      1aA  1eH     1     5   T   E    A    H    1    2  ...  1.019345
# 124     1aA  3aL     1    15   T   N    A    L    1    2  ...  1.019345
# 246     1aA  5aC     1    29   T   V    A    C    1    3  ...  1.019345
# 669     1aE  4gP     1    28   T   Q    E    P    3    1  ...  1.050685
# 1083    1aG  2gD     1    14   T   Q    G    D    2    2  ...  0.977402
# ...     ...  ...   ...   ...  ..  ..  ...  ...  ...  ...  ...       ...
# 107198  5dV  3fV    32    20   L   S    V    V    1    2  ...  0.693624
# 107299  5dW  1gG    32     7   L   K    W    G    3    2  ...  0.937554
# 107404  5dW  4aP    32    22   L   A    W    P    3    1  ...  0.937554
# 107518  5dY  1fL    32     6   L   E    Y    L    3    2  ...  0.950280
# 107579  5dY  3gG    32    21   L   T    Y    G    3    2  ...  0.950280
#
#          s2_mean      epi1      epi2      epi3       epi         p       fdr  \
# ...
